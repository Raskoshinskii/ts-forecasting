# %% [markdown]
# ### EDA по анализу временных рядов

# %%
import pandas as pd
import numpy as np

from scripts.preprocessing import preprocess_dataframe

# %%
preprocess_dataframe(df='s')
# Out:
# 'ok'
